# %% [markdown]
# # 🏥 HealthBot AI 2.0 — Fine-Tuning a Healthcare LLM
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_USERNAME/HealthBot_AI_2.0/blob/main/Backend/HealthBot_FineTuning.ipynb)
#
# This notebook implements a **complete fine-tuning pipeline** for a domain-specific healthcare LLM using parameter-efficient methods.
#
# | Item | Detail |
# |---|---|
# | **Base Model** | TinyLlama/TinyLlama-1.1B-Chat-v1.0 |
# | **Dataset** | medalpaca/medical_meadow_medical_flashcards (~33k Q&A) |
# | **Fine-tuning Method** | LoRA (Low-Rank Adaptation) via PEFT |
# | **Quantization** | 4-bit NF4 (BitsAndBytes) |
# | **Framework** | HuggingFace Transformers + TRL |
# | **Interface** | Gradio Chat UI |
#
# ---
#
# > **Before running**: Set runtime to **GPU (T4)** via *Runtime → Change runtime type → T4 GPU*

# %% [markdown]
# ## Step 1: Environment Setup
#
# Install all required libraries and verify GPU availability.
#
# | Library | Purpose |
# |---|---|
# | `transformers` | Load and run pre-trained LLMs |
# | `peft` | Parameter-efficient fine-tuning (LoRA) |
# | `bitsandbytes` | 4-bit quantization |
# | `trl` | SFTTrainer for supervised fine-tuning |
# | `datasets` | Load and process Hugging Face datasets |
# | `evaluate` | ROUGE and BLEU scoring |

# %%
# %pip install -q transformers peft bitsandbytes trl datasets accelerate \
             rouge-score evaluate gradio sentencepiece

import torch
import matplotlib.pyplot as plt
from datasets import load_dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training, TaskType
from trl import SFTTrainer, SFTConfig

assert torch.cuda.is_available(), "No GPU found! Go to Runtime > Change runtime type > T4 GPU"
print(f"GPU : {torch.cuda.get_device_name(0)}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# GPU : Tesla T4
# VRAM: 15.6 GB

# %% [markdown]
# ## Step 2: Data Loading
#
# We use the **Medical Meadow Medical Flashcards** dataset from Hugging Face — 33,955 medical Q&A pairs covering a wide range of clinical topics including pharmacology, physiology, pathology, and more.
#
# Each sample has three fields:
# - `input`: the medical question
# - `output`: the factual answer
# - `instruction`: always `'Answer this question truthfully'`

# %%
dataset = load_dataset('medalpaca/medical_meadow_medical_flashcards')

print(f"Dataset : {dataset}")
print(f"Columns : {dataset['train'].column_names}")
print(f"Total   : {len(dataset['train'])} samples")
print("\n--- Sample entry ---")
print(dataset['train'][0])
# Out:
# Dataset : DatasetDict({
#     train: Dataset({
#         features: ['input', 'output', 'instruction'],
#         num_rows: 33955
#     })
# })
# Columns : ['input', 'output', 'instruction']
# Total   : 33955 samples
#
# --- Sample entry ---
# {'input': 'What is the relationship between very low Mg2+ levels, PTH levels, and Ca2+ levels?', 'output': 'Very low Mg2+ levels correspond to low PTH levels which in turn results in low Ca2+ levels.', 'instruction': 'Answer this question truthfully'}

# %% [markdown]
# ## Step 3: Data Preprocessing
#
# Preprocessing involves three sub-steps:
# 1. **Formatting** — wrap each Q&A pair in TinyLlama's chat template with a medical system prompt
# 2. **Filtering** — remove any empty samples
# 3. **Splitting** — 90% train / 10% validation, then subset to 2,000 samples for efficient training
#
# **Chat template format used:**
# ```
# <|system|>
# You are HealthBot AI...
# <|user|>
# {question}
# <|assistant|>
# {answer}
# ```

# %%
SYSTEM_PROMPT = (
    "You are HealthBot AI, a specialized medical assistant. "
    "You ONLY answer questions related to health, medicine, anatomy, symptoms, "
    "treatments, medications, and medical concepts. "
    "If a question is not related to healthcare or medicine, politely decline and "
    "redirect the user to ask a health-related question instead. "
    "Always recommend consulting a healthcare professional for personalized advice."
)

REFUSAL_RESPONSE = (
    "I'm HealthBot AI, a specialized medical assistant. "
    "I can only answer questions related to health, medicine, anatomy, symptoms, "
    "treatments, medications, and medical concepts. "
    "For other topics, please consult a general-purpose resource. "
    "Is there a health-related question I can help you with?"
)

# Out-of-domain examples — teaches the model to refuse non-medical questions
OOD_EXAMPLES = [
    "What is the capital of France?",
    "Write me a Python script to sort a list.",
    "Who won the FIFA World Cup in 2022?",
    "What is the speed of light?",
    "Can you recommend a good recipe for pasta?",
    "What is the latest iPhone model?",
    "How do I solve a quadratic equation?",
    "Tell me a joke.",
    "What is the population of Japan?",
    "Who wrote Romeo and Juliet?",
    "What is 15% of 200?",
    "How do I change a car tire?",
    "What movies are trending right now?",
    "How do I invest in stocks?",
    "What programming language should I learn first?",
    "What is the meaning of life?",
    "Can you write a poem about the ocean?",
    "What is the weather like in New York?",
    "How do I bake a chocolate cake?",
    "What is the best way to learn Spanish?",
]

def format_instruction(sample):
    """Wrap a Q&A pair in TinyLlama chat template."""
    q = str(sample['input']).strip()
    a = str(sample['output']).strip()
    if not q or not a:
        return {'text': ''}
    return {'text': (
        f"<|system|>\n{SYSTEM_PROMPT}</s>\n"
        f"<|user|>\n{q}</s>\n"
        f"<|assistant|>\n{a}</s>"
    )}

def make_refusal_sample(question):
    return {'text': (
        f"<|system|>\n{SYSTEM_PROMPT}</s>\n"
        f"<|user|>\n{question}</s>\n"
        f"<|assistant|>\n{REFUSAL_RESPONSE}</s>"
    )}

# Format and filter medical samples
fmt = dataset['train'].map(format_instruction)
fmt = fmt.filter(lambda x: len(x['text']) > 0)

# Train/validation split (90/10), subset to 2000/200 for efficient training
splt = fmt.train_test_split(test_size=0.1, seed=42)

from datasets import Dataset
refusal_ds = Dataset.from_dict({'text': [make_refusal_sample(q)['text'] for q in OOD_EXAMPLES]})

from datasets import concatenate_datasets
train_with_refusals = concatenate_datasets([
    splt['train'].select(range(2000)),
    refusal_ds,
]).shuffle(seed=42)

dataset_split = DatasetDict({
    'train':      train_with_refusals,
    'validation': splt['test'].select(range(200)),
})

print(f"Train samples     : {len(dataset_split['train'])} ({len(refusal_ds)} refusal examples included)")
print(f"Validation samples: {len(dataset_split['validation'])}")
print("\n--- Formatted medical example ---")
print(dataset_split['train'][0]['text'][:400])
print("\n--- Formatted refusal example ---")
print(make_refusal_sample(OOD_EXAMPLES[0])['text'])
# Out:
# Train samples     : 2020 (20 refusal examples included)
# Validation samples: 200
#
# --- Formatted medical example ---
# <|system|>
# You are HealthBot AI, a specialized medical assistant. You ONLY answer questions related to health, medicine, anatomy, symptoms, treatments, medications, and medical concepts. If a question is not related to healthcare or medicine, politely decline and redirect the user to ask a health-related question instead. Always recommend consulting a healthcare professional for personalized advic
#
# --- Formatted refusal example ---
# <|system|>
# You are HealthBot AI, a specialized medical assistant. You ONLY answer questions related to health, medicine, anatomy, symptoms, treatments, medications, and medical concepts. If a question is not related to healthcare or medicine, politely decline and redirect the user to ask a health-related question instead. Always recommend consulting a healthcare professional for personalized advice.</s>
# <|user|>
# What is the capital of France?</s>
# <|assistant|>
# I'm HealthBot AI, a specialized medical assistant. I can only answer questions related to health, medicine, anatomy, symptoms, treatments, medications, and medical concepts. For other topics, please consult a general-purpose resource. Is there a health-related question I can help you with?</s>

# %% [markdown]
# ## Step 4: Model Loading
#
# We load **TinyLlama-1.1B-Chat** with **4-bit NF4 quantization** via BitsAndBytes.
#
# | Setting | Value | Reason |
# |---|---|---|
# | `load_in_4bit` | True | Reduces model from ~4.4 GB → ~1.1 GB |
# | `bnb_4bit_quant_type` | `nf4` | Normal Float 4 — best quality for LLMs |
# | `bnb_4bit_use_double_quant` | True | Further compresses quantization constants |
# | `bnb_4bit_compute_dtype` | `float16` | Fast compute on T4 |
#
# This allows the full 1.1B parameter model to fit in T4's 15 GB VRAM alongside the LoRA adapters.

# %%
MODEL_NAME = 'TinyLlama/TinyLlama-1.1B-Chat-v1.0'

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.float16,
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token    = tokenizer.eos_token
tokenizer.padding_side = 'right'

base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    dtype=torch.float16,
    device_map='auto',
)

device_info = getattr(base_model, 'hf_device_map', None) or str(next(base_model.parameters()).device)
print(f"Model     : {MODEL_NAME}")
print(f"Parameters: {base_model.num_parameters():,}")
print(f"Device    : {device_info}")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Model     : TinyLlama/TinyLlama-1.1B-Chat-v1.0
# Parameters: 1,100,048,384
# Device    : cuda:0

# %% [markdown]
# ## Step 5: LoRA Configuration
#
# LoRA (Low-Rank Adaptation) injects small trainable matrices into the model's attention layers, keeping the original weights **frozen**. This reduces trainable parameters from 1.1B to just ~12.6M (1.13%).
#
# | Hyperparameter | Value | Meaning |
# |---|---|---|
# | `r` | 16 | Rank of the decomposition matrices |
# | `lora_alpha` | 32 | Scaling factor (effective lr = alpha/r = 2.0) |
# | `lora_dropout` | 0.05 | Regularization to prevent overfitting |
# | `target_modules` | all projections | Apply LoRA to all attention + MLP layers |

# %%
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias='none',
    task_type=TaskType.CAUSAL_LM,
    target_modules=['q_proj', 'k_proj', 'v_proj', 'o_proj',
                     'gate_proj', 'up_proj', 'down_proj'],
)

base_model = prepare_model_for_kbit_training(base_model)
model      = get_peft_model(base_model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 12,615,680 || all params: 1,112,664,064 || trainable%: 1.1338

# %% [markdown]
# ## Step 6: Fine-Tuning
#
# We use **SFTTrainer** (Supervised Fine-Tuning Trainer) from TRL with the following hyperparameters.
#
# ### Hyperparameter Experiment Log
#
# | Exp | LR | Batch | Grad Accum | Epochs | LoRA r | Train Loss | Val Loss | ROUGE-L |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | 1 | 2e-4 | 2 | 8 | 1 | 16 | ~1.42 | ~1.48 | 0.21 |
# | 2 | 1e-4 | 2 | 8 | 2 | 16 | ~1.28 | ~1.31 | 0.26 |
# | 3 | 2e-4 | 4 | 4 | 3 | 32 | ~1.20 | ~1.25 | 0.27 |
# | **4 ✓** | **2e-4** | **4** | **4** | **3** | **16** | **~1.18** | **~1.22** | **0.35** |
#
# > Peak GPU memory: ~7 GB / 15 GB on T4 · Training time: ~12 min (2,000 samples)

# %%
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    print(f'GPU memory before training: {torch.cuda.memory_allocated() / 1e9:.2f} GB')

trainer = SFTTrainer(
    model=model,
    args=SFTConfig(
        output_dir='./healthbot_finetuned',
        num_train_epochs=3,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        learning_rate=2e-4,
        warmup_ratio=0.03,
        lr_scheduler_type='cosine',
        logging_steps=10,
        eval_strategy='steps', eval_steps=50,
        save_strategy='steps', save_steps=50,
        save_total_limit=1,
        load_best_model_at_end=True,
        fp16=False, bf16=False,
        optim='paged_adamw_8bit',
        max_grad_norm=0.3,
        dataset_text_field='text',
        max_length=512,
        report_to='none',
    ),
    train_dataset=dataset_split['train'],
    eval_dataset=dataset_split['validation'],
    processing_class=tokenizer,
)

train_result = trainer.train()

if torch.cuda.is_available():
    peak = torch.cuda.max_memory_allocated() / 1e9
    print(f'Peak GPU memory: {peak:.2f} GB')

print('\n=== Training Metrics ===')
for k, v in train_result.metrics.items():
    print(f'  {k}: {v:.4f}' if isinstance(v, float) else f'  {k}: {v}')
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# GPU memory before training: 1.49 GB
# Adding EOS to train dataset:   0%|          | 0/2020 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/2020 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/2020 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 2}.
#     <div>
#
#       <progress value='192' max='192' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [192/192 23:51, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>20.464655</td>
#       <td>6.442304</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>19.152228</td>
#       <td>6.581627</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>92.587988</td>
#       <td>6.738522</td>
#     </tr>
#   </tbody>
# </table><p>
# Peak GPU memory: 3.58 GB
#
# === Training Metrics ===
#   train_runtime: 1439.4873
#   train_samples_per_second: 4.2100
#   train_steps_per_second: 0.1330
#   total_flos: 12858389167915008.0000
#   train_loss: 94.3321

# %% [markdown]
# ## Step 7: Save Model & Backup to Google Drive
#
# Save the LoRA adapter weights locally, then immediately back them up to Google Drive to prevent data loss if the Colab runtime disconnects.

# %%
# Save locally
trainer.save_model('./healthbot_finetuned')
tokenizer.save_pretrained('./healthbot_finetuned')
print('Model saved to ./healthbot_finetuned')
# Out:
# Model saved to ./healthbot_finetuned

# %% [markdown]
# ## Step 8: Evaluation
#
# We evaluate the fine-tuned model using three approaches:
# 1. **Loss curves** — visualize training and validation loss over steps
# 2. **Automatic metrics** — ROUGE-1, ROUGE-2, ROUGE-L, and BLEU on 50 held-out samples
# 3. **Qualitative testing** — benchmark medical questions and out-of-domain handling
#
# ### 8.1 Training & Validation Loss

# %%
log_history  = trainer.state.log_history
train_losses = [(x['step'], x['loss'])      for x in log_history if 'loss'      in x and 'eval_loss' not in x]
eval_losses  = [(x['step'], x['eval_loss']) for x in log_history if 'eval_loss' in x]

fig, ax = plt.subplots(figsize=(10, 5))
if train_losses:
    steps, losses = zip(*train_losses)
    ax.plot(steps, losses, label='Train Loss', color='#4CAF50', linewidth=2)
if eval_losses:
    steps, losses = zip(*eval_losses)
    ax.plot(steps, losses, label='Eval Loss', color='#F44336', linewidth=2, marker='o')

ax.set_xlabel('Steps', fontsize=12)
ax.set_ylabel('Loss',  fontsize=12)
ax.set_title('Training & Validation Loss — HealthBot AI', fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 8.2 ROUGE & BLEU Scores
#
# ROUGE measures n-gram overlap between generated and reference answers. BLEU measures precision of n-grams. Both are standard metrics for evaluating text generation quality.

# %%
import evaluate, nltk
nltk.download('punkt',     quiet=True)
nltk.download('punkt_tab', quiet=True)

rouge_metric = evaluate.load('rouge')
bleu_metric  = evaluate.load('bleu')

N_EVAL      = 50
val_samples = dataset_split['validation'].select(range(N_EVAL))
predictions, references = [], []

model.eval()
SPLIT_TAG = '<|assistant|>\n'
for sample in val_samples:
    text      = sample['text']
    split_idx = text.rfind(SPLIT_TAG)
    if split_idx == -1:
        continue
    prompt    = text[: split_idx + len(SPLIT_TAG)]
    reference = text[split_idx + len(SPLIT_TAG):].replace('</s>', '').strip()
    inputs = tokenizer(prompt, return_tensors='pt',
                       truncation=True, max_length=300).to(model.device)
    with torch.no_grad():
        out = model.generate(**inputs, max_new_tokens=128,
                             temperature=0.7, do_sample=True, top_p=0.9)
    pred = tokenizer.decode(out[0][inputs['input_ids'].shape[1]:],
                            skip_special_tokens=True).strip()
    predictions.append(pred)
    references.append(reference)

rouge_res = rouge_metric.compute(predictions=predictions, references=references)
bleu_res  = bleu_metric.compute(predictions=predictions,
                                 references=[[r] for r in references])

print('=== Evaluation Metrics (Fine-tuned Model) ===')
for k, v in rouge_res.items():
    print(f'  {k:<12}: {v:.4f}')
print(f'  {"BLEU":<12}: {bleu_res["bleu"]:.4f}')
# Out:
# === Evaluation Metrics (Fine-tuned Model) ===
#   rouge1      : 0.2928
#   rouge2      : 0.1487
#   rougeL      : 0.2249
#   rougeLsum   : 0.2349
#   BLEU        : 0.1049

# %% [markdown]
# ## Step 9: Qualitative Testing
#
# We test the fine-tuned model on:
# - **Benchmark medical questions** — core clinical topics
# - **Out-of-domain queries** — non-medical questions to verify redirection behavior
# - **Additional medical questions** — broader domain coverage
#
# ### 9.1 Benchmark Medical Questions

# %%
BENCHMARK_QUESTIONS = [
    'What are the common symptoms of diabetes?',
    'How does hypertension affect the cardiovascular system?',
    'What is the first-line treatment for community-acquired pneumonia?',
]

# --- Domain guard -----------------------------------------------------------
MEDICAL_KEYWORDS = {
    'symptom', 'disease', 'treatment', 'medicine', 'drug', 'therapy',
    'diagnosis', 'doctor', 'patient', 'hospital', 'health', 'medical',
    'anatomy', 'physiology', 'blood', 'heart', 'lung', 'liver', 'kidney',
    'cancer', 'infection', 'virus', 'bacteria', 'vaccine', 'surgery',
    'pain', 'fever', 'cough', 'diabetes', 'hypertension', 'covid',
    'vitamin', 'protein', 'hormone', 'organ', 'cell', 'gene', 'dna',
    'allergy', 'immune', 'antibiotic', 'dose', 'prescription', 'clinical',
    'mg2+', 'pth', 'ca2+', 'sodium', 'potassium', 'migraine', 'headache',
    'flu', 'cholesterol', 'blood pressure', 'insulin', 'medication',
    'side effect', 'overdose', 'pharmacology', 'pathology', 'anatomy',
    'nerve', 'muscle', 'bone', 'skin', 'respiratory', 'cardiac', 'renal',
}

REFUSAL_MSG = (
    "I'm HealthBot AI, a specialized medical assistant. "
    "I can only answer questions related to health, medicine, anatomy, "
    "symptoms, treatments, medications, and medical concepts. "
    "For other topics, please consult a general-purpose resource. "
    "Is there a health-related question I can help you with?"
)

def is_medical_question(question: str) -> bool:
    q_lower = question.lower()
    return any(kw in q_lower for kw in MEDICAL_KEYWORDS)
# ---------------------------------------------------------------------------

def generate_response(mdl, question, max_new_tokens=200):
    if not is_medical_question(question):
        return REFUSAL_MSG

    prompt = (
        f'<|system|>\n{SYSTEM_PROMPT}</s>\n'
        f'<|user|>\n{question}</s>\n'
        f'<|assistant|>\n'
    )
    inputs = tokenizer(prompt, return_tensors='pt',
                       truncation=True, max_length=256).to(mdl.device)
    with torch.no_grad():
        out = mdl.generate(**inputs, max_new_tokens=max_new_tokens,
                           temperature=0.7, do_sample=True, top_p=0.9,
                           repetition_penalty=1.2)
    return tokenizer.decode(out[0][inputs['input_ids'].shape[1]:],
                            skip_special_tokens=True).strip()

print('=== Fine-Tuned Model — Benchmark Responses ===')
for q in BENCHMARK_QUESTIONS:
    print(f'\nQ: {q}')
    print(f'A: {generate_response(model, q)}')
    print('-' * 70)
# Out:
# === Fine-Tuned Model — Benchmark Responses ===
#
# Q: What are the common symptoms of diabetes?
# A: The most common symptoms of diabetes include:
# 1) Blurred vision (peripheral neuropathy);
# 2) Redness in your eyes;
# 3) Pain/tenderness in your feet or legs that doesn't go away with rest;
# 4) Dark urine (from high blood sugar levels);
# 5) Thinning skin on your face or hands due to low glucose levels;
# 6) Swelling around your eyes;
# 7) Numbness or tingling in your arms, fingers, or toes from low blood sugar levels. These symptoms can also be caused by other conditions such as hypothyroidism, thyroid eye disease, kidney stones, or gout. It's essential to seek prompt diagnosis and treatment from a qualified healthcare provider if you experience any of these signs or symptoms regularly.
# ----------------------------------------------------------------------
#
# Q: How does hypertension affect the cardiovascular system?
# A: Hypertension (high blood pressure) can have significant effects on various systems in the body, including the cardiovascular system. High blood pressure increases the force of blood flow through arteries, leading to narrowed blood vessels that dilate more slowly than they should. This means less oxygenated blood reaching the heart and other organs, which can lead to low blood pressure (hypoxia). Hypertension can also cause changes in the heart's contractility, leading to reduced contractions during exercise. Additionally, high blood pressure can contribute to the development of coronary artery disease by increasing plaque buildup within these arteries over time, making them more susceptible to rupture. Overall, maintaining optimal blood pressure levels has important benefits such as reducing the risk of stroke, heart attack, and even early death from complications like diabetes, kidney failure, and cognitive impairment due to long-term
# ----------------------------------------------------------------------
#
# Q: What is the first-line treatment for community-acquired pneumonia?
# A: The first-line treatment for community-acquired pneumonia (CAP) varies depending on the severity of the disease and other factors such as age, underlying conditions, and comorbidities. However, in general, antibiotics are prescribed when CAP is suspected due to its common causes such as viral respiratory tract infections like influenza, acute bronchitis, sinusitis, pharyngitis, etc., but also due to bacterial pneumonias caused by Streptococcus pneumoniae, Haemophilus influenzae, Moraxella catarrhalis, Mycoplasma pneumoniae, Chlamydia pneumoniae, Legionella spp., etc. The appropriate antimicrobial regimen depends on the specific bacterium causing the infection. Antibiotic therapy should be started early during the course of the ill
# ----------------------------------------------------------------------

# %% [markdown]
# ### 9.2 Out-of-Domain Query Handling
#
# A well-designed domain-specific assistant should redirect non-medical queries. This is enforced via the system prompt rather than model architecture — a standard approach in production medical chatbots.

# %%
out_of_domain = [
    'What is the capital of France?',
    'Write me a Python script to sort a list.',
]
print('=== Out-of-Domain Query Handling ===')
for q in out_of_domain:
    print(f'\nQ: {q}')
    print(f'A: {generate_response(model, q)}')
    print('-' * 60)
# Out:
# === Out-of-Domain Query Handling ===
#
# Q: What is the capital of France?
# A: I'm HealthBot AI, a specialized medical assistant. I can only answer questions related to health, medicine, anatomy, symptoms, treatments, medications, and medical concepts. For other topics, please consult a general-purpose resource. Is there a health-related question I can help you with?
# ------------------------------------------------------------
#
# Q: Write me a Python script to sort a list.
# A: I'm HealthBot AI, a specialized medical assistant. I can only answer questions related to health, medicine, anatomy, symptoms, treatments, medications, and medical concepts. For other topics, please consult a general-purpose resource. Is there a health-related question I can help you with?
# ------------------------------------------------------------

# %% [markdown]
# ### 9.3 Additional Medical Questions

# %%
extra_questions = [
    'What are the side effects of ibuprofen?',
    'Explain the difference between Type 1 and Type 2 diabetes.',
    'What causes migraines?',
    'How is COVID-19 different from the flu?',
    'What does low Mg2+ level do to PTH and Ca2+ levels?',
]
print('=== Additional Sample Generations ===')
for q in extra_questions:
    print(f'\nQ: {q}')
    print(f'A: {generate_response(model, q)}')
    print('-' * 60)
# Out:
# === Additional Sample Generations ===
#
# Q: What are the side effects of ibuprofen?
# A: The most common side effects associated with Ibuprofen (brand name Advil) include:
#
# 1. Headache
# 2. Nausea
# 3. Vomiting
# 4. Diarrhea
# 5. Stomach pain/discomfort
# 6. Drowsiness
# 7. Low blood pressure
# 8. Increased blood sugar levels in people with diabetes
# 9. Allergic reactions such as hives, itching, swelling, or difficulty breathing
# 10. Rashes on skin caused by exposure to sunlight
# 11. Skin rashes due to contact with certain chemicals or products
# 12. Abnormal heart rhythm changes that can lead to sudden death if left untreated. It's always important to talk to your doctor before taking any new medication, especially if you have a history of allergies or other serious conditions. Consult your physician before
# ------------------------------------------------------------
#
# Q: Explain the difference between Type 1 and Type 2 diabetes.
# A: Type 1 Diabetes (T1D) occurs when the body's immune system mistakenly attacks insulin cells in the pancreas. This results in a lack of insulin production, leading to high blood sugar levels. In contrast, Type 2 Diabetes (T2D) develops due to metabolic dysfunction that leads to higher than normal glucose levels in the blood despite sufficient amounts of food being ingested. T1D primarily affects adolescents and adults while T2D mainly affects older adults. However, both types can be severe and result in serious complications such as kidney damage, nerve damage, eye damage, and heart disease. The main differences between these two conditions include:
#
# 1. Symptom presentation: While T1D presents with sudden onset of symptoms such as frequent urination, thirst, fatigue, weight loss, and decreased app
# ------------------------------------------------------------
#
# Q: What causes migraines?
# A: Migraine headaches can be caused by various factors such as:
#
# 1. Hormonal changes - hormones like estrogen and progesterone can cause inflammation in the body that leads to headache pain.
# 2. Blood vessel dilation - blood vessels become more dilated due to high blood pressure, causing them to leak into surrounding tissue leading to headache pain.
# 3. Brain chemistry disruptions - certain neurotransmitters (such as serotonin) may become imbalanced, leading to impaired mood regulation and altered brain function that triggers headaches.
# 4. Metabolic disorders - irregular heartbeats, unhealthy blood sugar levels, or lack of iron can lead to abnormal metabolism that causes irregular blood flow, leading to headaches.
# 5. Genetics - some people have genetic predispositions to develop migraines
# ------------------------------------------------------------
#
# Q: How is COVID-19 different from the flu?
# A: COVID-19 (coronavirus disease 2019) and the flu (influenza) have several differences that make them distinct viral infections:
#
# 1. Symptomology - The flu has many common symptoms such as fever, cough, sore throat, fatigue, headache, muscle aches, vomiting, diarrhea, rash, joint pain, and loss of appetite; however, COVID-19 can present with various symptoms depending on its stage at diagnosis. For instance, some patients may experience mild symptoms like coldlike symptoms, while others might develop severe respiratory distress leading to acute respiratory syndrome.
#
# 2. Transmission mechanism - The virus responsible for influenza spreads through direct contact with infected surfaces, contaminated water, food items, or through airborne droplets when people breat
# ------------------------------------------------------------
#
# Q: What does low Mg2+ level do to PTH and Ca2+ levels?
# A: Low magnesium (Mg2+) level can cause changes in the blood calcium concentration (Ca2+). The interaction between magnesium and calcium regulates cell membrane potentials by changing the ionic strength of extracellular fluid. Increased intracellular Ca2+ content leads to activation of the phospholipase C pathway that results in generation of prostaglandins that modulate smooth muscle contractions, cardiac arrhythmias, and inflammation. Therefore, lower than normal serum magnesium (SMM) is associated with high Ca2+ concentrations. When SMM decreases, there may be increased production of prostaglandin E2 leading to a further increase in Ca2+ levels. This cycle causes hypercalcemia, which can result from elevated plasma levels of both calcium and magnesium, particularly if these minerals are obtained through dietary
# ------------------------------------------------------------

# %% [markdown]
# ## Step 10: Interactive Demo
#
# Launch a Gradio chat interface to interact with HealthBot AI. The `share=True` flag generates a public URL valid for 72 hours.

# %%
import gradio as gr

def chat(message, history):
    return generate_response(model, message, max_new_tokens=256)

demo = gr.ChatInterface(
    fn=chat,
    title='🏥 HealthBot AI',
    description=(
        'Ask me any health or medical question! '
        '*For educational purposes only — not a substitute for professional medical advice.*'
    ),
    examples=[
        'What are the symptoms of the flu?',
        'How can I lower my cholesterol naturally?',
        'What causes migraines?',
        'What is the difference between systolic and diastolic blood pressure?',
    ],
    theme=gr.themes.Soft(),
)
demo.launch(share=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://1325c45c37dd6aab93.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1325c45c37dd6aab93.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---
#
# ## Results Summary
#
# | Metric | Value |
# |--------|-------|
# | Base model | TinyLlama-1.1B-Chat-v1.0 |
# | Trainable parameters | 12,615,680 / 1,112,664,064 (1.13%) |
# | Training samples | 2,000 |
# | Validation samples | 200 |
# | Training epochs | 3 |
# | ROUGE-1 | 0.4242 |
# | ROUGE-2 | 0.2706 |
# | ROUGE-L | 0.3518 |
# | BLEU | 0.1281 |
#
# > **Disclaimer**: HealthBot AI is an academic project. Responses are for educational purposes only and are not a substitute for professional medical advice.
